# %%
import pandas as pd
import numpy as np
from sodapy import Socrata
import seaborn as sns

# %%
client = Socrata("data.cityofnewyork.us", None)
results = client.get("h9gi-nx95", limit=2000)
main_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
main_df_sorted=main_df.sort_values(by="number_of_persons_injured")
main_df_sorted.head(5)
# Out:
#                    crash_date crash_time            on_street_name  \
# 999   2021-04-14T00:00:00.000      19:00                       NaN
# 1148  2021-04-16T00:00:00.000      18:25             RICHMOND ROAD
# 1147  2021-04-15T00:00:00.000      10:20            WEST 44 STREET
# 1917  2022-03-26T00:00:00.000      16:35                  AVENUE U
# 1144  2021-04-15T00:00:00.000       7:35  BRONX RIVER PARKWAY RAMP
#
#       off_street_name number_of_persons_injured number_of_persons_killed  \
# 999               NaN                         0                        0
# 1148  COLUMBUS AVENUE                         0                        0
# 1147         7 AVENUE                         0                        0
# 1917   COLEMAN STREET                         0                        0
# 1144              NaN                         0                        0
#
#      number_of_pedestrians_injured number_of_pedestrians_killed  \
# ...

# %%
sns.displot(data=main_df_sorted, x="number_of_persons_injured")
